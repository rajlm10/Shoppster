# %% [markdown]
# <a href="https://colab.research.google.com/github/rajlm10/Shoppster/blob/main/Pretraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-6r30rwaf
#   Running command git clone -q https://github.com/huggingface/transformers /tmp/pip-req-build-6r30rwaf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 7.6 MB 29.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 49.6 MB/s
# ...
#   Created wheel for transformers: filename=transformers-4.25.0.dev0-py3-none-any.whl size=5778385 sha256=870583901e7a3fd6569d141cfc29d9719823c8ebc6d0634cc2bc51b6ea9c45dd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ot_ewrh0/wheels/35/2e/a7/d819e3310040329f0f47e57c9e3e7a7338aa5e74c49acfe522
# Successfully built transformers
# ...

# %%
# !python -c "from transformers import pipeline; print(pipeline('sentiment-analysis')('I love you'))"
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading: 100% 629/629 [00:00<00:00, 502kB/s]
# Downloading: 100% 268M/268M [00:03<00:00, 68.0MB/s]
# Downloading: 100% 48.0/48.0 [00:00<00:00, 41.4kB/s]
# Downloading: 100% 232k/232k [00:00<00:00, 261kB/s]
# [{'label': 'POSITIVE', 'score': 0.9998656511306763}]

# %%
# !pip install torch>=1.5.0
# !pip install torchvision>=0.6.0
# !pip install datasets>=1.8.0

# %%
# !nvidia-smi
# Out:
# Fri Nov 25 18:50:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python run_mae.py \
    --model_name_or_path google/vit-base-patch16-224-in21k \
    --dataset_name ashraq/fashion-product-images-small \
    --output_dir ./mae_4_epochs \
    --remove_unused_columns False \
    --label_names pixel_values \
    --mask_ratio 0.85 \
    --norm_pix_loss \
    --do_train \
    --do_eval \
    --base_learning_rate 1.5e-4 \
    --lr_scheduler_type cosine \
    --weight_decay 0.05 \
    --num_train_epochs 4 \
    --warmup_ratio 0.05 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --fp16 \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --seed 1337
# Out:
# WARNING:__main__:Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True
# INFO:__main__:Training/evaluation parameters CustomTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# base_learning_rate=0.00015,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=epoch,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# ...

# %%
# !cp -a /content/mae_4_epochs /content/drive/MyDrive/MLD/MAE

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python run_mim.py \
    --model_type vit \
    --model_name_or_path google/vit-base-patch16-224-in21k \
    --dataset_name ashraq/fashion-product-images-small \
    --output_dir ./mim_4_epochs/ \
    --overwrite_output_dir \
    --remove_unused_columns False \
    --label_names bool_masked_pos \
    --do_train \
    --do_eval \
    --learning_rate 2e-5 \
    --weight_decay 0.05 \
    --num_train_epochs 4 \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --logging_strategy steps \
    --logging_steps 100 \
    --evaluation_strategy epoch \
    --fp16 \
    --save_strategy epoch \
    --load_best_model_at_end True \
    --save_total_limit 3 \
    --seed 1337
# Out:
# WARNING:__main__:Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True
# INFO:__main__:Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=epoch,
# fp16=True,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# ...

# %%
# !cp -a /content/mim_4_epochs /content/drive/MyDrive/MLD/MIM
